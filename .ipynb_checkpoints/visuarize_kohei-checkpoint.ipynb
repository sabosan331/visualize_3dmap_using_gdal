# %% [markdown]
# # install library
# * conda install mayavi
# * conda install gdal-python
# → libpng version problem # only for mac
# * brew update && brew upgrade

# %% [markdown]
# # install library
# * conda install gdal
# * pip install mayavi

# %%
"""
Plotting the terrain DEM with Mayavi2
"""
from osgeo import gdal
import numpy as np
from mayavi import mlab

ds = gdal.Open('dem.tiff')
print(ds)
data = ds.ReadAsArray()

print(data.shape)

data = data.astype(np.float32)

mlab.figure(size=(640, 800), bgcolor=(0.16, 0.28, 0.46))

surf = mlab.surf(data, warp_scale=0.2) 
mlab.show()
# Out:
# <osgeo.gdal.Dataset; proxy of <Swig Object of type 'GDALDatasetShadow *' at 0x12ffb6cc0> >
# (324, 368)

# %%
dataset = gdal.Open('dem.tiff')
data = dataset.ReadAsArray()
print(data.shape)
# Out:
# (324, 368)

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
plt.gray()
plt.imshow(data)
# Out:
# <img src="data:image/png;base64,..." width="639.85">
